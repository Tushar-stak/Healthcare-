# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %% [markdown]
# ### Week 1--Data Exploration:
#
#
# ### 1. Perform descriptive analysis. Understand the variables and their corresponding values. On the columns below, a value of zero does not make sense and thus indicates missing value:
# #### • Glucose
# #### • BloodPressure
# #### • SkinThickness
# #### • Insulin
# #### • BMI
# ### 2. Visually explore these variables using histograms. Treat the missing values accordingly.
# ### 3. There are integer and float data type variables in this dataset. Create a count (frequency) plot describing the data types and the count of variables.

# %%
df=pd.read_csv("C:/Users/Tushar/Downloads/data science/6.Data science capstone/project 2 healthcare/Project_2..dataset/Project 2/Healthcare - Diabetes/health care diabetes.csv")

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print(df.size)
print(df.shape)
print(df.head())
# Out:
# 6912
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.hist(figsize = (20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000A0A1608>,
# ...
#       dtype=object)

# %%
df.hist(column='Glucose', bins=20,grid=True,figsize=(16,8), color='blue', rwidth=0.95)
plt.xlabel('Glucose')
plt.ylabel('Number of subjects')
plt.title('Visualization of Glucose')
#plt.xlim(0, 200)
#plt.ylim(0, 120)
#A=[0,20,40,60,80,100,120]
A = np.linspace(0,120,20)
#B= np.linspace(0,200,22)
plt.yticks(A)
plt.xticks(np.linspace(0,200,22))
plt.show()

# %%
df1 = df.copy(deep =True)
df1[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = df1[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)



df1.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df1['Glucose'].fillna(df1['Glucose'].mean(), inplace = True)
df1['BloodPressure'].fillna(df1['BloodPressure'].mean(), inplace = True)
df1['SkinThickness'].fillna(df1['SkinThickness'].median(), inplace = True)
df1['Insulin'].fillna(df1['Insulin'].median(), inplace = True)
df1['BMI'].fillna(df1['BMI'].median(), inplace = True)

# %%
df1.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df1.hist(figsize = (20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B4F8F88>,
# ...
#       dtype=object)

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# 1. From the given data set number of independent and dependent variables are eight and one respectively.
# 2. Size of data is 6912. The shape of given data frame is (768,9) representing number of rows and columns respectively
# 3. Given data set contains integer and float data types only.
# 4. here outcome is our independent variable, we are finding out the mean ,std,min,max,count of every variable.
# 5. Performing data cleaning to find missing values in the data frame. Considering zero value as a missing value it is obsrve that data set contains columns glucose, blood pressure, isulin, skinthikness and BMI with zero values.
# 6. To plot histogram charts for the above mentioned variables zero values are replaced by NAN. After that NAN is replaced by mean or median values of concerned variables.

# %%
#sns.countplot(y=df.dtypes,data=df)
plt.figure(figsize=(10,8))
sns.countplot(df.dtypes.map(str))

plt.title('Count (frequency) plot of the data types and the count of variables',fontsize=20)
plt.xlabel("Data Types",fontsize=15)
plt.ylabel("Count of variables",fontsize=15)
#plt.grid(True)
plt.grid(axis='y', alpha=0.75)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ### Week 2--Data Exploration:
#
# ### 1. Check the balance of the data by plotting the count of outcomes by their value. Describe your findings and plan future course of action.
# ### 2. Create scatter charts between the pair of variables to understand the relationships. Describe your findings.
# ### 3. Perform correlation analysis. Visually explore it using a heat map.

# %%
import missingno as msno

# %%
p=msno.bar(df)

# %%
color_wheel={1:"#0392cf",
             2:"#7bc043"}
colors=df["Outcome"].map(lambda x: color_wheel.get(x+1))
print(df.Outcome.value_counts())

plt.figure(figsize=(10,8))

df.Outcome.value_counts().plot(kind="bar")


plt.title('Plot of the count of outcomes by their value',fontsize=20)
plt.xlabel("Outcomes",fontsize=15)
plt.ylabel("Count of outcomes",fontsize=15)
plt.grid(axis='y', alpha=0.75)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.show()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# 1. A bar represents a plot of outcome and corresponding number of patients.
# 2. Data set consists of two types of outcomes, 0 and 1 representing non-diabetic and diabetic patient respectively.
# 3. From the plot, 268 patients are daibetic and remaining 500 are non-diabetic.

# %%
from sklearn import datasets
# %matplotlib inline

plt.style.use('ggplot')

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize=(30,40))
plt.show()

# %%
plt.figure(figsize=(30,40))

#sns.set(font_scale=1.2)
sns.pairplot(df,hue='Outcome')
plt.show()

# %% [markdown]
#     In the scatter plot all variables are pairing with each other. Consider one example for understanding BMI vs AGE, In our dataframe most of  BMI is  in between the age of 20 to 65 and BMI is decreses after incresing age of patient.

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %% [markdown]
# 1. Correlation is used to test relationship between two variables.
# 2. Correlation coefficient  ranges (-1 to +1). 1 is indicate the positive corrlation ,0 is indicate the no correlation and -1 is indicate the negative correlation between them.consider example for better understanding the relationship between AGE vs AGE is 1 i.e.positive correlation & AGE vs Insulin is -0.042 i.e. negative correlation.

# %%
plt.figure(figsize=(15,10))
sns.set(font_scale=1.2)

ax=sns.heatmap(df.corr(),annot=True,cmap= 'Blues',vmin=-1, vmax=+1)

bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)

plt.show()

# %% [markdown]
# ### Week 3-Data Modeling:
# #### 1. Devise strategies for model building. It is important to decide the right validation framework. Express your thought process.
# #### 2. Apply an appropriate classification algorithm to build a model. Compare various models with the results from KNN algorithm.
#
#
# ### Week 3-Data Modeling:
# #### 1. Create a classification report by analyzing sensitivity, specificity, AUC (ROC curve), etc. Please be descriptive to explain what values of these parameter you have used.

# %%
x = df.iloc [:,:-1].values
y = df.iloc [:,8].values

# %% [markdown]
# 1. Three models are used in this work, KNN ,Random forest and logistic regression.
# 2. Starting with seperation of x variable and corresponding y variable.
# 3. Seperated x and y data is divided into test and train data for modelling and measurement purpose, onsidering 80% for training and 20% for testing purpose.
# 4. Training data used for model building and test data is used for measuring accuracy and other measurements like f1 score, recall, precision.
# 5. Various maodels are compaired with kNN. On the basis of accuracy and other measuring parameters such as f1 score, recall, precision it is observed that Logistic regression Logistic better than the other algorithms model.
# 6. Last one is the AUC(area under curve)-ROC(receive operating characteristics curve)

# %%
x.shape
# Out:
# (768, 8)

# %%
y.shape
# Out:
# (768,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2,random_state = 0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
#from sklearn import metrics

# %%
test_scores = []
train_scores = []

for i in range(1,15):

    knn = KNeighborsClassifier(i)
    knn.fit(x_train,y_train)
    
    train_scores.append(knn.score(x_train,y_train))
    test_scores.append(knn.score(x_test,y_test))

# %%
max_train_score = max(train_scores)
train_scores_ind = [i for i, v in enumerate(train_scores) if v == max_train_score]
print('Max train score {} % and k = {}'.format(max_train_score*100,list(map(lambda x: x+1, train_scores_ind))))
# Out:
# Max train score 100.0 % and k = [1]

# %%
max_test_score = max(test_scores)
test_scores_ind = [i for i, v in enumerate(test_scores) if v == max_test_score]
print('Max test score {} % and k = {}'.format(max_test_score*100,list(map(lambda x: x+1, test_scores_ind))))
# Out:
# Max test score 79.22077922077922 % and k = [10, 13, 14]

# %%
plt.figure(figsize=(12,5))
p = sns.lineplot(range(1,15),train_scores,marker='*',label='Train Score')
p = sns.lineplot(range(1,15),test_scores,marker='o',label='Test Score')

# %%
knn_model = KNeighborsClassifier(n_neighbors=6) 
knn_model.fit(x_train,y_train)
knn_pred=knn_model.predict(x_test)

# %%
print("Model Validation ==>\n")
print("Accuracy Score of KNN Model::")
print(accuracy_score(y_test,knn_pred))
print("\n","Classification Report::")
print(classification_report(y_test,knn_pred),'\n')
# Out:
# Model Validation ==>
#
# Accuracy Score of KNN Model::
# 0.7792207792207793
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       107
#            1       0.67      0.55      0.60        47
#
#     accuracy                           0.78       154
#    macro avg       0.74      0.72      0.73       154
# weighted avg       0.77      0.78      0.77       154

# %%
#import confusion_matrix
from sklearn.metrics import confusion_matrix

#let us get the predictions using the classifier we had fit above
y_pred = knn.predict(x_test)
confusion_matrix(y_test,y_pred)
pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted    0   1  All
# True
# 0           96  11  107
# 1           21  26   47
# All        117  37  154

# %%
y_pred = knn.predict(x_test)

from sklearn import metrics

cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
p = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')

plt.ylim(len(np.unique(y))-0, -0)

plt.title('Confusion matrix')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print("\n","ROC Curve")

knn_prob=knn_model.predict_proba(x_test)
knn_prob1=knn_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,knn_prob1)

roc_auc_knn=metrics.auc(fpr,tpr)


plt.figure(dpi=120)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_knn)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
#  ROC Curve

# %% [markdown]
# ### logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
''''
model = LogisticRegression() 
model.fit(x_train,y_train)
'''
lr_model = LogisticRegression(C=0.01) 
lr_model.fit(x_train,y_train)
lr_pred=lr_model.predict(x_test)

# %%
print("Model Validation ==>\n")

print("Accuracy Score of Logistic Regression Model::")
print(accuracy_score(y_test,lr_pred))

print("\n","Classification Report::")
print(metrics.classification_report(y_test,lr_pred),'\n')
# Out:
# Model Validation ==>
#
# Accuracy Score of Logistic Regression Model::
# 0.7402597402597403
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82       107
#            1       0.61      0.43      0.50        47
#
#     accuracy                           0.74       154
#    macro avg       0.69      0.65      0.66       154
# weighted avg       0.72      0.74      0.73       154

# %%
#import confusion_matrix
from sklearn.metrics import confusion_matrix

#let us get the predictions using the classifier we had fit above
y_pred = lr_model.predict(x_test)
confusion_matrix(y_test,y_pred)
pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted    0   1  All
# True
# 0           94  13  107
# 1           27  20   47
# All        121  33  154

# %%
y_pred = lr_model.predict(x_test)

from sklearn import metrics

cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
p = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')

plt.ylim(len(np.unique(y))-0, -0)

plt.title('Confusion matrix')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print("\n","ROC Curve")

lr_prob=lr_model.predict_proba(x_test)

lr_prob1=lr_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,lr_prob1)
roc_auc_lr=metrics.auc(fpr,tpr)


plt.figure(dpi=120)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_lr)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
#  ROC Curve

# %% [markdown]
# ### Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=1000,random_state=0)
rf_model.fit(x_train,y_train)
rf_pred=rf_model.predict(x_test)

# %%
print("Model Validation ==>\n")
print("Accuracy Score of Logistic Regression Model::")
print(metrics.accuracy_score(y_test,rf_pred))
print("\n","Classification Report::")
print(metrics.classification_report(y_test,rf_pred),'\n')
# Out:
# Model Validation ==>
#
# Accuracy Score of Logistic Regression Model::
# 0.8181818181818182
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87       107
#            1       0.72      0.66      0.69        47
#
#     accuracy                           0.82       154
#    macro avg       0.79      0.77      0.78       154
# weighted avg       0.81      0.82      0.82       154

# %%
#import confusion_matrix
from sklearn.metrics import confusion_matrix

#let us get the predictions using the classifier we had fit above
y_pred = rf_model.predict(x_test)
confusion_matrix(y_test,y_pred)
pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted    0   1  All
# True
# 0           95  12  107
# 1           16  31   47
# All        111  43  154

# %%
y_pred = rf_model.predict(x_test)

from sklearn import metrics

cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
p = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')

plt.ylim(len(np.unique(y))-0, -0)

plt.title('Confusion matrix')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print("\n","ROC Curve")

rf_prob=rf_model.predict_proba(x_test)
rf_prob1=rf_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,rf_prob1)
roc_auc_rf=metrics.auc(fpr,tpr)


plt.figure(dpi=120)
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_rf)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
#  ROC Curve

# %%
#for knn
#import GridSearchCV
from sklearn.model_selection import GridSearchCV
#In case of classifier like knn the parameter to be tuned is n_neighbors
param_grid = {'n_neighbors':np.arange(1,50)}
knn = KNeighborsClassifier()
knn_cv= GridSearchCV(knn,param_grid,cv=5)
knn_cv.fit(x,y)

print("Best Score:" + str(knn_cv.best_score_))
print("Best Parameters: " + str(knn_cv.best_params_))
# Out:
# Best Score:0.7578125
# Best Parameters: {'n_neighbors': 14}

# %%
# for logistic regression
#import GridSearchCV

from sklearn.model_selection import GridSearchCV
#In case of classifier like knn the parameter to be tuned is n_neighbors

param_grid = {'C':np.logspace(-3,3,7), "penalty":["l1","l2"]}
lr_model = LogisticRegression()
lr_cv= GridSearchCV(lr_model,param_grid,cv=5)
lr_cv.fit(x,y)

#lr_cv.fit(x_train,y_train)
print("Best Score:" + str(lr_cv.best_score_))
print("Best Parameters: " + str(lr_cv.best_params_))

#print("tuned hpyerparameters :(best parameters) ",lr_cv.best_params_)
#print("accuracy :",lr_cv.best_score_)
# Out:
# Best Score:0.7721354166666666
# Best Parameters: {'C': 100.0, 'penalty': 'l2'}

# %%
#for Random forest
#import GridSearchCV
from sklearn.model_selection import GridSearchCV
#In case of classifier like knn the parameter to be tuned is n_neighbors
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

rf_model = RandomForestClassifier(random_state=42)
rf_cv= GridSearchCV(rf_model,param_grid,cv=5)
rf_cv.fit(x,y)

print("Best Score:" + str(rf_cv.best_score_))
print("Best Parameters: " + str(rf_cv.best_params_))
# Out:
# Best Score:0.7760416666666666
# Best Parameters: {'criterion': 'gini', 'max_depth': 6, 'max_features': 'auto', 'n_estimators': 200}
